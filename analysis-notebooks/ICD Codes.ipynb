# %%
import pandas as pd

# %%
df = pd.read_csv('./icd_codes_combined.csv', index_col=0)

# %%
df
# Out:
#       icd_code                                      icd_code_desc  \
# 0         A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1         A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2         A009                               Cholera, unspecified
# 3        A0100                         Typhoid fever, unspecified
# 4        A0101                                 Typhoid meningitis
# ...        ...                                                ...
# 81126     U995                                                NaN
# 81127     U996                                                NaN
# 81128     U997                                                NaN
# 81129     U998                                                NaN
# 81130     U999                                                NaN
#
#                                         icd_code_desc_de
# 0      Cholera durch Vibrio cholerae O:1, Biovar chol...
# 1        Cholera durch Vibrio cholerae O:1, Biovar eltor
# ...

# %%
df_bothExist = df.dropna()

# %%
df_bothExist
# Out:
#       icd_code                                      icd_code_desc  \
# 0         A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1         A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2         A009                               Cholera, unspecified
# 10        A011                                Paratyphoid fever A
# 11        A012                                Paratyphoid fever B
# ...        ...                                                ...
# 72612     Z990                            Dependence on aspirator
# 72615     Z992                       Dependence on renal dialysis
# 72616     Z993                           Dependence on wheelchair
# 72619     U070                            Vaping-related disorder
# 72620     U071                                           COVID-19
#
#                                         icd_code_desc_de
# 0      Cholera durch Vibrio cholerae O:1, Biovar chol...
# 1        Cholera durch Vibrio cholerae O:1, Biovar eltor
# ...
