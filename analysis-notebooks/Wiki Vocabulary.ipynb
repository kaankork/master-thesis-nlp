# %%
import pandas as pd
import nltk

# %%
# !pwd
# Out:
# /Users/kaankorkmaz/projects_KK/thesis/analysis

# %%
df = pd.read_csv('/Users/kaankorkmaz/projects_KK/thesis/data/vocabulary/germanwiki_vocab.csv')

# %%
df[1000:1050]
# Out:
#                            0
# 1000                 (Stand:
# 1001                    Juli
# 1002               2020)[14]
# 1003                  Einige
# 1004             Krankheiten
# 1005                  gelten
# 1006               rechtlich
# 1007                     nur
# 1008                    dann
# 1009                     als
# 1010      Berufskrankheiten,
# 1011                    wenn
# 1012                     sie
# 1013                   durch
# 1014             Tätigkeiten
# 1015                      in
# 1016              bestimmten
# 1017    Gefährdungsbereichen
# 1018              verursacht
# 1019                  worden
# 1020               sind.[11]
# 1021                    Dazu
# 1022                 gehören
# 1023          beispielsweise
# 1024  Infektionskrankheiten.
# 1025                   Diese
# 1026                  werden
# 1027           grundsätzlich
# 1028                     nur
# 1029                    dann
# 1030                     als
# ...

# %%
df.value_counts()[10000:10050]
# Out:
# 0
# blauen                   12
# Bergsucht                12
# Lungenerkrankungen       12
# Schritten                12
# Dr.                      12
# Entzündungsparameter     12
# behandelnde              12
# genannt),                12
# lieferte                 12
# wird:                    12
# François                 12
# günstiger                12
# Objekte                  12
# vor.[1]                  12
# infrage                  12
# Aulus                    12
# Blutkulturen             12
# Kopf-Hals-Bereich        12
# Punktionen               12
# Lippen-                  12
# molekulare               12
# fehlt,                   12
# machten                  12
# War                      12
# Gelenkerguss             12
# beruht,                  12
# infolgedessen            12
# Deformierung             12
# Umwelt,                  12
# erleiden,                12
# VCD                      12
# Objekt                   12
# verpflichtet,            12
# ...
